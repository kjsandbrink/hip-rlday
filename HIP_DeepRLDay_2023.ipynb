# %% [markdown]
# <a href="https://colab.research.google.com/github/kjsandbrink/hip-rlday/blob/main/HIP_DeepRLDay_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to the algorithms & agents reinforcement learning workshop!
#
# ---
#
# #### HIP Lab Deep RL Day 2023
#
# This notebook has as goal to introduce basic concepts about algorithms & agents in (policy gradient) reinforcement learning. We will begin by creating a small sample environment, creating an agent, and then taking a look at the training loop. We start out by using simple *REINFORCE* before adding in a baseline to get *REINFORCE with baseline* before finally constructing an *advantage actor-critic (A2C).*
#
# There are 3-4 exercises of varying difficulty for each.
#
# ## REINFORCE
#
# The environment we will build is a correlated bandit task.

# %%
import numpy as np
import math
import torch
from torch import nn
from torch.distributions import Categorical
from collections import deque
import matplotlib.pyplot as plt

# %%
class TwoArmedGaussianBandit:

    def __init__(self, mean_mag, reward_var, n_steps, center=0):
        ''' Initializes correlated two-armed bandit task for bandits that have the same variance but opposing means

        Arguments
        ---------
        mean_mag : float, variance in means for distribution from which bandit arm means will be drawn (centered around 0)
        reward_var : float, variance for distribution on each arm mean from which reward will be sampled
        n_steps : int, number of steps in an episode
        center : float, number around which arms are centered
        '''
        self.mean_mag = mean_mag
        self.reward_var = reward_var
        self.n_steps = n_steps
        self.center = center

    def reset(self):
        ''' Resamples new bandit arm probabilities, to be called at the beginning of every episode'''

        # sample mean rewards
        self.mean = [self.mean_mag + self.center, -self.mean_mag + self.center]
        np.random.shuffle(self.mean)

        ## reset counter_steps to 0
        self.counter_steps = 0

        return [0]

    def step(self, action):
        """
        Arguments
        ---------
        action (int): the selected action.

        Returns
        -------
        observation : np.array; here, only contains the reward
        reward : float
        done : bool, True: the episode has terminated; False: otherwise
        info : dict info for debugging
        """

        reward = np.random.normal(self.mean[action], math.sqrt(self.reward_var))

        self.counter_steps += 1
        done = (self.counter_steps == self.n_steps)
        return np.array([reward]), reward, done, self.mean

# %% [markdown]
# As you can see, the environment has a reset function (to be called at the beginning of every episode) and a step function (to be called on every step when the agent interacts with the environment).
#
# We next define our REINFORCE actor network. This network is copied from networks.py from the DeepRLDay GitHub repository we will be using if you attend the afternoon session.

# %%
class PolicyRNN(nn.Module):

    def __init__(self, n_actions, n_inputs, hidden_size=32):
        ''' Initializes an RNN to compute the agent policy

        Arguments
        ---------
        n_actions : int, number of actions the agent should have
        n_inputs : int, size of feature space
        hidden_size : int, size of LSTM layer
        '''

        super().__init__()
        self.n_actions = n_actions
        self.n_inputs = n_inputs
        self.hidden_size = hidden_size
        torch.manual_seed(1)
        self.initialize_model()

    def initialize_model(self):
        ''' Build the network
        '''

        self.lstm = nn.LSTMCell(self.n_inputs, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.n_actions)
        self.logits = nn.LogSoftmax(dim=0)

    def forward(self, x, lstm_hidden = None):
        ''' Compute network forward pass

        Arguments
        ---------
        lstm_hidden : tuple (hidden, cell)
          h_h : tensor with hidden state
          h_c : tensor with cell statee
        '''

        if lstm_hidden is None:
            lstm_h, lstm_c = self.lstm(x)
        else:
            lstm_h, lstm_c = self.lstm(x, lstm_hidden)
        out = self.out(lstm_h)
        logits = self.logits(out)

        return logits, (lstm_h, lstm_c)

# %% [markdown]
# Now there we have a network that can approximate our policy, we are ready to create an agent class so that we can look at each of the components in turn. The agent class has some methods missing completely and others only instantiated partially - can you complete the missing components?

# %%
class ReinforceAgent:

    def __init__(self, n_actions, n_inputs, hidden_size, learning_rate, gamma = 0.99):
        '''  Initializes an agent using Monte Carlo REINFORCE

        Arguments
        ---------
        n_actions : int, number of actions the agent should have
        n_inputs : int, size of feature space
        hidden_size : int, size of LSTM layer
        learning_rate : float, the learning rate used to train the network
        gamma : float, discount factor
        '''

        self.gamma = gamma ## discount factor
        self.n_actions = n_actions
        self.policy = PolicyRNN(n_actions, n_inputs, hidden_size)
        self.optimizer = torch.optim.Adam(self.policy.parameters(), lr = learning_rate)
        self.history = []
        self.batch_losses = []
        self.episode_rewards = []
        self.episode_log_probs = []

    def choose_action(self, observation):

        ''' Selects an action by using the policy network. Can you fill this on?

        Arguments
        ---------
        observation : np.array [1, n_features]

        Returns
        -------
        action : int between 0 and n_action - 1
        '''

        state = torch.tensor(observation, dtype=torch.float32)
        log_probs, self.lstm_hidden = self.policy(state, self.lstm_hidden)

        ### EXERCISE 1: The network specified above returns log probabilities ("logits") corresponding to the agent policy.
        ### Can you use this probability to sample an action? Usually, this is done using the torch "Categorical"
        ### distribution object which is already imported above
        ### Remember that we need to save the log probability corresponding to our chosen action afterward -- append this to episode_log_probs

        lp = Categorical(logits = log_probs)
        action = lp.sample()

        return action.detach().numpy().item()

    def store_transition(self, observation, action, reward, next_observation):
        ''' Add the current transition to history and current rewards to episode_rewards (which keeps track of episodes earned so far)

        Arguments
        ---------
        observation : np.array or tensor [1, n_features]
        action : int
        reward : float
        next_observation : np.array or tensor [1, n_features]
        '''
        self.history.append((observation, action, reward, next_observation))
        self.episode_rewards.append(reward)

    def reset(self):
        ''' Resets the network so that it can be called for a new episode '''
        self.lstm_hidden = None

        ## reset self.episode_rewards and self.episode_log_probs to 0
        self.episode_rewards = []
        self.episode_log_probs = []

    def calculate_episode_loss(self):
        ''' This function is called at the end of an episode to calculate the loss
        using self.episode_rewards and self.episode_log_probs.
        The loss is then appended to self.batch_losses and self.episode_rewards
        and self.episode_log_probs reset.
        '''

        R = 0

        ## compute cumulative rewards from each time point (=returns)
        returns = deque()
        for r in self.episode_rewards[::-1]:

            #### EXERCISE 2: We are looping through our returns backwards step-by-step
            #### in order to compute the cumulative rewards from each time point.
            #### We then prepend these to the deque.
            #### Can you compute cumulative returns at each step and save them to "R"?

            #### YOUR CODE HERE

            returns.appendleft(R)
        returns = torch.tensor(returns)

        ## normalize rewards, with eps to avoid div by zero
        returns = (returns - returns.mean()) / (returns.std() + np.finfo(np.float32).eps.item())

        ## convert episode_log_probs to tensor (remember that this contains the log probabilities corresponding to the actions we took)
        episode_log_probs = torch.stack(self.episode_log_probs)

        #### EXERCISE 3: Now there we have both the cumulative reward from each time point as well as our episode_log_probs,
        #### we compute our policy gradient loss for the episode and save it to policy_loss.
        #### Can you do this keeping in mind the formulas learned from Aniruddh's lecture?


        self.batch_losses.append(policy_loss)

        return policy_loss.detach().item()

    def batch_learn(self):
        ''' This function performs a gradient update based on the batched episodes.
        At the end, self.batch_losses is reset to an empty list.

        Arguments
        ---------
        self

        Returns
        -------
        batch_loss : float, loss over the current batch
        '''

        ## take optimizer step
        self.optimizer.zero_grad()
        batch_loss = torch.stack(self.batch_losses).mean()
        batch_loss.backward()
        self.optimizer.step()

        self.batch_losses = []

        return batch_loss.detach().item()

# %% [markdown]
# Now, let's put it all together in a training loop!

# %%
# %% PARAMETERS
n_steps = 20
n_episodes = 10000
batch_size = 50
hidden_size = 16
learning_rate = 1e-3
gamma = 0.99 #discount factor

# %% INITIALIZATIONS
env = TwoArmedGaussianBandit(10, 0.1, n_steps)
agent = ReinforceAgent(n_actions = 2, n_inputs = 1, hidden_size = hidden_size,  learning_rate = learning_rate, gamma = gamma)
score_history = []
pg_losses = []

for i in range(n_episodes):

    done = False
    score = 0
    observation = env.reset()
    agent.reset()

    while not done:
        ### EXERCISE 4: The next functions encode the interactions between agent and the environment.
        ### The agent needs to choose an action, interact with the environment, store the transition,
        ### and finally update the observation and score variables.
        ### Most of these pieces already exist in the module functions - can you put them all together?

        ### YOUR CODE HERE

    score_history.append(score)
    episode_loss = agent.calculate_episode_loss()
    pg_losses.append(episode_loss)
    avg_score = np.mean(score_history[-50:])
    avg_loss = np.mean(pg_losses[-50:])

    if i % (n_episodes // 10) == 0:
      print('episode ', i, 'score  %.1f' % score, 'avg score %.1f' % avg_score, 'loss %.1f' % episode_loss, 'avg_loss %.1f' % avg_loss)

    ### call learning function after each batch
    if i!=0 and i % batch_size == 0:
      agent.batch_learn()
# Out:
# episode  0 score  79.6 avg score 79.6 loss -0.4 avg_loss -0.4
# episode  100 score  38.1 avg score 7.4 loss -0.6 avg_loss 0.0
# episode  200 score  -78.0 avg score 7.0 loss 0.4 avg_loss 0.1
# episode  300 score  -97.7 avg score 3.5 loss 0.2 avg_loss 0.0
# episode  400 score  -18.5 avg score -5.0 loss -0.7 avg_loss 0.1
# episode  500 score  -81.9 avg score 0.4 loss -0.2 avg_loss -0.1
# episode  600 score  -60.1 avg score -11.0 loss 0.4 avg_loss 0.0
# episode  700 score  121.4 avg score 5.6 loss -0.3 avg_loss -0.1
# episode  800 score  -59.4 avg score 2.0 loss 0.3 avg_loss 0.0
# episode  900 score  41.1 avg score -0.5 loss -0.4 avg_loss 0.0
# episode  1000 score  -59.0 avg score -7.4 loss 0.4 avg_loss 0.0
# episode  1100 score  -58.9 avg score 4.7 loss 0.5 avg_loss 0.1
# episode  1200 score  40.2 avg score 2.8 loss -0.6 avg_loss -0.1
# episode  1300 score  -2.3 avg score 7.8 loss -0.3 avg_loss -0.0
# episode  1400 score  -38.7 avg score -7.2 loss 0.2 avg_loss -0.0
# episode  1500 score  0.5 avg score 7.9 loss -0.7 avg_loss -0.1
# episode  1600 score  18.7 avg score 2.2 loss -0.7 avg_loss -0.0
# episode  1700 score  -81.0 avg score -0.7 loss 0.2 avg_loss 0.0
# episode  1800 score  -21.9 avg score -1.6 loss -1.1 avg_loss 0.1
# episode  1900 score  139.0 avg score -1.1 loss -1.4 avg_loss -0.0
# episode  2000 score  62.2 avg score 9.2 loss 0.0 avg_loss 0.0
# episode  2100 score  -119.4 avg score -8.1 loss -0.3 avg_loss 0.1
# episode  2200 score  -57.4 avg score 1.9 loss 0.1 avg_loss -0.2
# episode  2300 score  -58.5 avg score 6.6 loss 0.4 avg_loss -0.1
# episode  2400 score  80.0 avg score -1.6 loss 0.9 avg_loss 0.1
# episode  2500 score  -23.6 avg score 22.7 loss -0.6 avg_loss -0.0
# episode  2600 score  38.4 avg score 14.1 loss -0.2 avg_loss -0.1
# episode  2700 score  -0.3 avg score 4.0 loss -1.1 avg_loss -0.2
# episode  2800 score  -81.5 avg score -7.0 loss 0.7 avg_loss -0.0
# episode  2900 score  119.6 avg score -2.9 loss -1.0 avg_loss 0.1
# episode  3000 score  -20.1 avg score 0.0 loss 1.0 avg_loss 0.0
# episode  3100 score  21.8 avg score 17.5 loss 1.7 avg_loss 0.4
# episode  3200 score  -40.3 avg score 7.9 loss 0.1 avg_loss 0.1
# episode  3300 score  98.6 avg score 5.4 loss 0.8 avg_loss 0.1
# episode  3400 score  -21.8 avg score 12.3 loss 0.6 avg_loss 0.0
# episode  3500 score  -0.8 avg score -1.1 loss 1.1 avg_loss -0.2
# episode  3600 score  -20.2 avg score 16.2 loss 0.6 avg_loss 0.1
# episode  3700 score  -59.5 avg score 4.7 loss -0.1 avg_loss 0.1
# episode  3800 score  -21.3 avg score 11.3 loss -1.2 avg_loss -0.1
# episode  3900 score  -41.4 avg score 21.8 loss 0.8 avg_loss 0.1
# episode  4000 score  19.0 avg score 22.7 loss 0.7 avg_loss -0.2
# episode  4100 score  -0.9 avg score 28.5 loss 0.8 avg_loss 0.2
# episode  4200 score  20.9 avg score 21.6 loss 1.0 avg_loss 0.0
# episode  4300 score  -40.7 avg score 4.3 loss 0.8 avg_loss -0.1
# episode  4400 score  -37.6 avg score 20.5 loss 1.3 avg_loss -0.1
# episode  4500 score  80.2 avg score 22.2 loss 0.8 avg_loss 0.2
# episode  4600 score  -40.6 avg score 6.9 loss -0.9 avg_loss -0.0
# episode  4700 score  118.5 avg score 28.4 loss -2.4 avg_loss 0.1
# episode  4800 score  -1.2 avg score 11.7 loss 0.8 avg_loss -0.2
# episode  4900 score  -40.3 avg score 11.8 loss -1.8 avg_loss 0.3
# episode  5000 score  -58.7 avg score 21.3 loss 0.1 avg_loss 0.3
# episode  5100 score  -23.2 avg score 39.0 loss 0.7 avg_loss -0.2
# episode  5200 score  21.6 avg score 28.9 loss 0.6 avg_loss 0.3
# episode  5300 score  57.9 avg score 33.7 loss -2.6 avg_loss 0.1
# episode  5400 score  0.2 avg score 23.5 loss 1.2 avg_loss 0.1
# episode  5500 score  20.7 avg score 39.3 loss 0.4 avg_loss 0.1
# episode  5600 score  40.5 avg score 43.8 loss 0.8 avg_loss 0.1
# episode  5700 score  19.8 avg score 30.5 loss 0.2 avg_loss -0.0
# episode  5800 score  -20.2 avg score 10.1 loss -1.1 avg_loss 0.0
# episode  5900 score  179.7 avg score 48.4 loss -1.5 avg_loss 0.1
# episode  6000 score  -21.5 avg score 38.6 loss 0.2 avg_loss 0.3
# episode  6100 score  38.8 avg score 42.7 loss -0.1 avg_loss 0.0
# episode  6200 score  180.0 avg score 46.2 loss 1.1 avg_loss 0.7
# episode  6300 score  2.0 avg score 27.4 loss -0.3 avg_loss 0.3
# episode  6400 score  -40.2 avg score 64.2 loss -1.8 avg_loss 0.6
# episode  6500 score  179.5 avg score 40.3 loss 1.6 avg_loss 0.2
# episode  6600 score  -20.4 avg score 61.4 loss -1.2 avg_loss 0.4
# episode  6700 score  -19.1 avg score 38.1 loss -0.4 avg_loss 0.3
# episode  6800 score  200.6 avg score 64.5 loss 1.2 avg_loss -0.1
# episode  6900 score  142.1 avg score 54.5 loss -0.3 avg_loss -0.3
# episode  7000 score  178.2 avg score 58.0 loss 3.8 avg_loss 0.3
# episode  7100 score  -18.3 avg score 39.6 loss -0.7 avg_loss -0.4
# episode  7200 score  -18.4 avg score 35.8 loss -2.5 avg_loss -0.1
# episode  7300 score  -118.5 avg score 50.2 loss -2.7 avg_loss -0.2
# episode  7400 score  42.2 avg score 64.7 loss 0.3 avg_loss 0.3
# episode  7500 score  -99.0 avg score 45.6 loss -0.2 avg_loss -0.1
# episode  7600 score  22.6 avg score 42.5 loss 1.2 avg_loss -0.3
# episode  7700 score  199.6 avg score 37.5 loss 1.2 avg_loss 0.1
# episode  7800 score  61.0 avg score 67.7 loss 0.2 avg_loss -0.1
# episode  7900 score  179.9 avg score 65.0 loss 0.2 avg_loss 0.2
# episode  8000 score  40.3 avg score 61.1 loss -2.3 avg_loss 0.0
# episode  8100 score  41.7 avg score 38.4 loss -2.1 avg_loss -0.3
# episode  8200 score  -119.4 avg score 68.5 loss -1.2 avg_loss 0.0
# episode  8300 score  62.7 avg score 64.7 loss 0.8 avg_loss 0.5
# episode  8400 score  59.0 avg score 38.6 loss 1.9 avg_loss -0.1
# episode  8500 score  198.9 avg score 68.6 loss 1.1 avg_loss -0.6
# episode  8600 score  60.0 avg score 46.6 loss -0.4 avg_loss -0.4
# episode  8700 score  59.9 avg score 61.1 loss -2.0 avg_loss -0.5
# episode  8800 score  -17.0 avg score 62.8 loss 1.4 avg_loss -0.0
# episode  8900 score  100.6 avg score 67.9 loss 0.5 avg_loss -0.3
# episode  9000 score  199.0 avg score 94.4 loss 1.0 avg_loss 0.0
# episode  9100 score  100.0 avg score 72.0 loss 0.5 avg_loss -0.0
# episode  9200 score  -119.9 avg score 57.9 loss -2.1 avg_loss -0.8
# episode  9300 score  181.0 avg score 81.8 loss 0.6 avg_loss -0.4
# episode  9400 score  78.0 avg score 69.8 loss 0.8 avg_loss 0.0
# episode  9500 score  199.2 avg score 76.5 loss 0.9 avg_loss 0.2
# episode  9600 score  39.9 avg score 56.6 loss 0.4 avg_loss -0.2
# episode  9700 score  61.4 avg score 54.5 loss -1.2 avg_loss -1.1
# episode  9800 score  161.1 avg score 65.7 loss 5.1 avg_loss -0.3
# episode  9900 score  198.8 avg score 89.1 loss 0.9 avg_loss 0.3

# %% [markdown]
# Now there we're done with the training loop, let's plot our progress! This part is already done so you should just be able to run the code block.

# %%
# %% PLOT LEARNING CURVE
fig, (ax1, ax2) = plt.subplots(1, 2, sharex='all', dpi=200)

## smooth rewards if necessary (moving average)
smoothing_window = n_episodes // 10
smoothed_rewards = np.convolve(score_history, np.ones(smoothing_window)/smoothing_window, mode='valid')
smoothed_losses = np.convolve(pg_losses, np.ones(smoothing_window)/smoothing_window, mode='valid')
episodes = np.array(range(n_episodes))[smoothing_window//2:-smoothing_window//2+1]

ax1.plot(episodes, smoothed_rewards)

fig.suptitle("Learning Curve")
ax1.set_xlabel("Episodes")
ax1.set_ylabel("Rewards")

ax2.plot(episodes, smoothed_losses)
ax2.set_xlabel("Episodes")
ax2.set_ylabel("Losses")
# Out:
# Text(0, 0.5, 'Losses')

# %% [markdown]
# ## REINFORCE with Baseline
#
# Sometimes, we encounter environments where the rewards are not neatly distributed around 0. In that case, it can be useful to re-center our rewards around 0 by introducing a baseline into our rewards function, which we will do in this section. As long as the baselines we use are only a function of the state and not of the action that we take they never perturb the equilibirum solution! In this section, we will look at constant baselines, but in the next section we will build on this to explore adaptive baselines that we can integrate by using a learned critic.
#
# Let's start by taking a look at what happens when we use the regular REINFORCE agent on an off-centered environment. The training loop below contains the same blanks as the one above, so feel free to copy in your solutions from there...

# %%
# %% PARAMETERS
n_steps = 20
n_episodes = 10000
batch_size = 50
hidden_size = 16
learning_rate = 1e-3
gamma = 0.99 #discount factor

# %% INITIALIZATIONS

### OFF-CENTER ENVIRONMENT
env = TwoArmedGaussianBandit(5, 0.1, n_steps, center=10) ## this time, the environment is off-center, i.e. arm means centered around 10
# we are also decreasing mean_mag so that our rewards are positive for both arms

agent = ReinforceAgent(n_actions = 2, n_inputs = 1, hidden_size = hidden_size,  learning_rate = learning_rate, gamma = gamma)
score_history = []
pg_losses = []

for i in range(n_episodes):

    done = False
    score = 0
    observation = env.reset()
    agent.reset()

    while not done:
        action = agent.choose_action(observation)
        next_observation, reward, done, info = env.step(action)
        agent.store_transition(observation, action, reward, next_observation)
        observation = next_observation
        score += reward

    score_history.append(score)
    episode_loss = agent.calculate_episode_loss()
    pg_losses.append(episode_loss)
    avg_score = np.mean(score_history[-50:])
    avg_loss = np.mean(pg_losses[-50:])

    if i % (n_episodes // 10) == 0:
      print('episode ', i, 'score  %.1f' % score, 'avg score %.1f' % avg_score, 'loss %.1f' % episode_loss, 'avg_loss %.1f' % avg_loss)

    ### call learning function after each batch
    if i!=0 and i % batch_size == 0:

      ### EXERCISE 5: Call the learn function

      agent.batch_learn()
# Out:
# episode  0 score  241.3 avg score 241.3 loss -0.3 avg_loss -0.3
# episode  1000 score  168.0 avg score 199.0 loss -0.0 avg_loss 0.0
# episode  2000 score  228.9 avg score 202.9 loss 0.0 avg_loss -0.0
# episode  3000 score  190.5 avg score 200.0 loss 0.1 avg_loss -0.0
# episode  4000 score  179.5 avg score 203.9 loss -0.2 avg_loss -0.0
# episode  5000 score  151.2 avg score 198.3 loss 0.1 avg_loss 0.0
# episode  6000 score  201.4 avg score 197.8 loss 0.2 avg_loss 0.1
# episode  7000 score  212.1 avg score 198.5 loss -0.2 avg_loss 0.0
# episode  8000 score  191.0 avg score 195.2 loss -0.3 avg_loss 0.0
# episode  9000 score  161.3 avg score 198.5 loss 0.2 avg_loss 0.1

# %%
# %% PLOT LEARNING CURVE
fig, (ax1, ax2) = plt.subplots(1, 2, sharex='all', dpi=200)

## smooth rewards if necessary (moving average)
smoothing_window = n_episodes // 10
smoothed_rewards = np.convolve(score_history, np.ones(smoothing_window)/smoothing_window, mode='valid')
smoothed_losses = np.convolve(pg_losses, np.ones(smoothing_window)/smoothing_window, mode='valid')
episodes = np.array(range(n_episodes))[smoothing_window//2:-smoothing_window//2+1]

ax1.plot(episodes, smoothed_rewards)

ax1.set_title("Learning Curve")
ax1.set_xlabel("Episodes")
ax1.set_ylabel("Rewards")

ax2.plot(episodes, smoothed_losses)
ax2.set_xlabel("Episodes")
ax2.set_ylabel("Losses")
# Out:
# Text(0, 0.5, 'Losses')

# %% [markdown]
# Now, let's try to fix this by incorporating an agent into our baseline!
#
# The agent below inherits from ReinforceAgent. Some of the blanks you can fill in from part 1, but you will need to add an additional part in calculate_episode_loss! Think about it: What baseline do you think makes the most sense to enter for an off-center, correlated bandit task?

# %%
class ReinforceWithBaselineAgent(ReinforceAgent):

    def calculate_episode_loss(self, baseline):
        ''' This function is called at the end of an episode to calculate the loss
        using self.episode_rewards and self.episode_log_probs.
        The loss is then appended to self.batch_losses and self.episode_rewards
        and self.episode_log_probs reset.

        Arguments
        ---------
        baseline : float, the baselines to compute

        '''

        R = 0

        ## compute cumulative rewards from each time point (=returns)
        returns = deque()
        for r in self.episode_rewards[::-1]:

            #### EXERCISE 1: We are looping through our returns backwards step-by-step
            #### in order to compute the cumulative rewards from each time point.
            #### We then prepend these to the deque.
            #### Can you compute cumulative returns at each step and save them to "R"?

            #### YOUR CODE HERE

            #### EXERCISE 2: Now, substract the baseline from the returns in order to re-center the results around 0.

            #### YOUR CODE HERE

            returns.appendleft(R)
        returns = torch.tensor(returns)

        ## normalize rewards, with eps to avoid div by zero
        returns = (returns - returns.mean()) / (returns.std() + np.finfo(np.float32).eps.item())

        ## convert episode_log_probs to tensor (remember that this contains the log probabilities corresponding to the actions we took)
        episode_log_probs = torch.stack(self.episode_log_probs)

        #### EXERCISE 3: Now there we have both the cumulative reward from each time point as well as our episode_log_probs,
        #### we compute our policy gradient loss for the episode and save it to policy_loss.
        #### Can you do this keeping in mind the formulas learned from Aniruddh's lecture?

        #### YOUR CODE HERE

        self.batch_losses.append(policy_loss)

        return policy_loss.detach().item()

# %%
# %% PARAMETERS
n_steps = 20
n_episodes = 10000
batch_size = 50
hidden_size = 16
learning_rate = 1e-3
gamma = 0.99 #discount factor

# %% INITIALIZATIONS
env = TwoArmedGaussianBandit(5, 0.1, n_steps, center=10) ## this time, the environment is off-center
agent = ReinforceWithBaselineAgent(n_actions = 2, n_inputs = 1, hidden_size = hidden_size,  learning_rate = learning_rate, gamma = gamma)
score_history = []
pg_losses = []

for i in range(n_episodes):

    done = False
    score = 0
    observation = env.reset()
    agent.reset()

    while not done:
        ### EXERCISE 4: The next functions encode the interactions between agent and the environment.
        ### The agent needs to choose an action, interact with the environment, store the transition,
        ### and finally update the observation and score variables.
        ### Most of these pieces already exist in the module functions - can you put them all together?

        ### YOUR CODE HERE

    score_history.append(score)


    ### EXERCISE 5: Call the calculate_episode_loss function while entering in an appropriate baseline

    ### YOUR CODE HERE

    pg_losses.append(episode_loss)
    avg_score = np.mean(score_history[-50:])
    avg_loss = np.mean(pg_losses[-50:])

    if i % (n_episodes // 10) == 0:
      print('episode ', i, 'score  %.1f' % score, 'avg score %.1f' % avg_score, 'loss %.1f' % episode_loss, 'avg_loss %.1f' % avg_loss)

    ### call learning function after each batch
    if i!=0 and i % batch_size == 0:

      agent.batch_learn()

# %%
# %% PLOT LEARNING CURVE
fig, (ax1, ax2) = plt.subplots(1, 2, sharex='all', dpi=200)

## smooth rewards if necessary (moving average)
smoothing_window = n_episodes // 10
smoothed_rewards = np.convolve(score_history, np.ones(smoothing_window)/smoothing_window, mode='valid')
smoothed_losses = np.convolve(pg_losses, np.ones(smoothing_window)/smoothing_window, mode='valid')
episodes = np.array(range(n_episodes))[smoothing_window//2:-smoothing_window//2+1]

ax1.plot(episodes, smoothed_rewards)

ax1.set_title("Learning Curve")
ax1.set_xlabel("Episodes")
ax1.set_ylabel("Rewards")

ax2.plot(episodes, smoothed_losses)
ax2.set_xlabel("Episodes")
ax2.set_ylabel("Losses")
# Out:
# Text(0, 0.5, 'Losses')

# %% [markdown]
# Much better, right? :)

# %% [markdown]
# ## A2C
#
# Now, we will move from REINFORCE to A2C. This will involve making two changes to the code which you will have heard about in Aniruddh's lecture:
#
# 1. Moving from REINFORCE to Actor-Critic: This will involve introducing a second network that represents value
# 2. From Monte Carlo to Advantage Learning: This means that instead of performing updates at the end of an episode (or a batch of episodes), we can now perform bootstrapping updates at an individual timestep based on the agent's value of estimate
#
# By combining these two steps, we will have successfully implemented the A2C algorithm.
#
# We begin by building a second network whose task will be to build a representation of value:

# %%
class CriticRNN(nn.Module):

    def __init__(self, n_inputs, hidden_size=32):

        super().__init__()
        self.n_inputs = n_inputs
        self.hidden_size = hidden_size
        torch.manual_seed(1)
        self.initialize_model()

    def initialize_model(self):

        self.lstm = nn.LSTMCell(self.n_inputs, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, 1)

    def forward(self, x, lstm_hidden = None):

        if lstm_hidden is None:
            lstm_h, lstm_c = self.lstm(x)
        else:
            lstm_h, lstm_c = self.lstm(x, lstm_hidden)
        out = self.out(lstm_h)

        return out, (lstm_h, lstm_c)

# %% [markdown]
# We now expand our agent to include this network, and update the learning algorithm to learn on every step. Here, again, there will be some parts for you to fill out!

# %%
class Agent:

    def __init__(self, n_actions, n_states, hidden_size, learning_rate, gamma = 0.99):

        self.gamma = gamma
        self.n_actions = n_actions
        self.actor= PolicyRNN(n_actions, n_states, hidden_size['actor'])
        self.critic = CriticRNN(n_states, hidden_size['critic'])
        self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr = learning_rate['actor'])
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), lr = learning_rate['critic'])
        self.history = []

    def reset(self):
        self.actor_hidden = None
        self.critic_hidden = None
        self.current_state_value = None

    def choose_action(self, observation):
        ''' Selects an action by using the policy network. Can you fill this on?

        Arguments
        ---------
        observation : np.array [1, n_features]

        Returns
        -------
        action : int between 0 and n_action - 1
        '''

        state = torch.tensor(observation, dtype=torch.float32)
        log_probs, self.actor_hidden = self.actor(state, self.actor_hidden)

        #### EXERCISE 1: Selection of action
        #### This works the same way as it did in the REINFORCE part, except instead of appending the log probability of the selected action
        #### to a list, we just save the fitted Categorical object so that we can use it to recover the logit later (since we are going step-by-step)
        #### Save the Categorical object to self.action_probs

        #### YOUR CODE HERE

        return action.detach().numpy().item()

    def store_transition(self, observation, action, reward, next_observation):
        self.history.append((observation, action, reward, next_observation))

    def learn(self, done):

        current_state, current_action,current_reward, next_state = self.history[-1]
        current_state = torch.tensor(current_state, dtype = torch.float32)
        next_state = torch.tensor(next_state, dtype = torch.float32)
        current_reward = torch.tensor(current_reward, dtype = torch.float32)
        current_action = torch.tensor(current_action, dtype = torch.float32)

        if self.current_state_value is None:
          self.current_state_value, self.critic_hidden = self.critic(current_state, self.critic_hidden)

        next_state_value, next_critic_hidden = self.critic(next_state, self.critic_hidden)

        ### EXERCISE 2: Calculate the TD Error from current_reward, next_state_value, and current_state_value
        ### (keeping in mind that you need to exclude next_state_value if you are in the last trial, i.e. if done is True)
        ### Save the result to td_error

        ### YOUR CODE HERE

        log_probs = self.action_probs.log_prob(current_action)

        ### EXERCISE 3: Calculate the separate actor and critic loss from the td_error and log_probs of chosen action
        ### Save the losses in actor_loss and critic_loss

        ### YOUR CODE HERE

        loss = actor_loss+critic_loss
        self.actor_optimizer.zero_grad()
        self.critic_optimizer.zero_grad()
        loss.backward()
        self.actor_optimizer.step()
        self.critic_optimizer.step()

        ### We detach the recurrent features because we are updating step-by-step
        self.current_state_value = next_state_value.detach()
        self.actor_hidden = (self.actor_hidden[0].detach(), self.actor_hidden[1].detach())
        self.critic_hidden = (next_critic_hidden[0].detach(), next_critic_hidden[1].detach())

        return actor_loss.item(), critic_loss.item()

# %% [markdown]
# We now make the needed modifications to the training loop. Because we are updating on every time step we use a smaller number of episodes

# %%
# %% PARAMETERS
n_steps = 20
n_episodes = 1000
#n_episodes = 100
batch_size = 50
hidden_size = 16
gamma = 0.99 #discount factor

# %% INITIALIZATIONS
env = TwoArmedGaussianBandit(10, 0.1, n_steps)

hidden_size = dict()
learning_rate = dict()

hidden_size['actor'] = 16
hidden_size['critic'] = 16

learning_rate['actor'] = 1e-3
learning_rate['critic'] = 1e-3

agent = Agent(n_actions = 2, n_states = 1, hidden_size = hidden_size,  learning_rate = learning_rate, gamma = gamma)
score_history = []
actor_losses = []
critic_losses = []

for i in range(n_episodes):

    done = False
    score = 0
    observation = env.reset()
    agent.reset()
    mean_actor_loss_in_episode = 0
    mean_critic_loss_in_episode = 0
    step_count = 0
    while not done:

        ### EXERCISE 4: The next functions encode the interactions between agent and the environment.
        ### The agent needs to choose an action, interact with the environment, store the transition,
        ### and finally update the observation and score variables, and finally - because here we are using TD -
        ### perform the learning update on every step (unlike the REINFORCE code above)!
        ### Most of these pieces already exist in the module functions - can you put them all together?

        ### YOUR CODE HERE

        actor_loss, critic_loss = agent.learn(done)
        mean_actor_loss_in_episode += actor_loss
        mean_critic_loss_in_episode += critic_loss
        step_count += 1

    mean_actor_loss_in_episode = mean_actor_loss_in_episode / step_count
    mean_critic_loss_in_episode = mean_critic_loss_in_episode / step_count

    score_history.append(score)
    actor_losses.append(mean_actor_loss_in_episode)
    critic_losses.append(mean_critic_loss_in_episode)
    avg_score = np.mean(score_history[-50:])

    if i % (n_episodes // 10) == 0:
      print('episode ', i, 'score  %.1f' % score, 'avg score %.1f' % avg_score, 'loss %.1f' % episode_loss, 'avg_loss %.1f' % avg_loss)
# Out:
# episode  0 score  -39.8 avg score -39.8
# episode  1 score  118.0 avg score 39.1
# episode  2 score  -80.5 avg score -0.8
# episode  3 score  -20.5 avg score -5.7
# episode  4 score  -38.2 avg score -12.2
# episode  5 score  -58.8 avg score -20.0
# episode  6 score  61.9 avg score -8.3
# episode  7 score  42.0 avg score -2.0
# episode  8 score  -21.9 avg score -4.2
# episode  9 score  -16.4 avg score -5.4
# episode  10 score  0.4 avg score -4.9
# episode  11 score  -0.3 avg score -4.5
# episode  12 score  40.6 avg score -1.0
# episode  13 score  -1.0 avg score -1.0
# episode  14 score  -40.8 avg score -3.7
# episode  15 score  -99.7 avg score -9.7
# episode  16 score  -20.2 avg score -10.3
# episode  17 score  -1.1 avg score -9.8
# episode  18 score  42.5 avg score -7.0
# episode  19 score  -40.8 avg score -8.7
# episode  20 score  60.0 avg score -5.5
# episode  21 score  -40.6 avg score -7.1
# episode  22 score  -20.8 avg score -7.7
# episode  23 score  -39.8 avg score -9.0
# episode  24 score  39.5 avg score -7.1
# episode  25 score  39.3 avg score -5.3
# episode  26 score  60.3 avg score -2.8
# episode  27 score  -17.2 avg score -3.4
# episode  28 score  -40.0 avg score -4.6
# episode  29 score  38.8 avg score -3.2
# episode  30 score  -21.7 avg score -3.8
# episode  31 score  -80.4 avg score -6.2
# episode  32 score  -80.3 avg score -8.4
# episode  33 score  64.0 avg score -6.3
# episode  34 score  -40.7 avg score -7.3
# episode  35 score  -83.4 avg score -9.4
# episode  36 score  -58.9 avg score -10.7
# episode  37 score  -42.3 avg score -11.6
# episode  38 score  -0.7 avg score -11.3
# episode  39 score  -21.2 avg score -11.5
# episode  40 score  -39.1 avg score -12.2
# episode  41 score  -21.9 avg score -12.4
# episode  42 score  58.2 avg score -10.8
# episode  43 score  -20.9 avg score -11.0
# episode  44 score  39.0 avg score -9.9
# episode  45 score  -40.1 avg score -10.6
# episode  46 score  -1.5 avg score -10.4
# episode  47 score  -39.4 avg score -11.0
# episode  48 score  40.8 avg score -9.9
# episode  49 score  40.8 avg score -8.9
# episode  50 score  -59.9 avg score -9.3
# episode  51 score  -18.2 avg score -12.0
# episode  52 score  18.7 avg score -10.0
# episode  53 score  -38.9 avg score -10.4
# episode  54 score  -19.0 avg score -10.0
# episode  353 score  -59.9 avg score 38.4
# episode  354 score  -77.3 avg score 37.2
# episode  355 score  -97.7 avg score 35.3
# episode  356 score  139.4 avg score 36.9
# episode  357 score  -77.8 avg score 32.5
# episode  358 score  160.8 avg score 32.5
# episode  359 score  -101.1 avg score 30.1
# episode  360 score  178.9 avg score 31.7
# episode  361 score  -60.4 avg score 31.6
# episode  362 score  158.0 avg score 35.6
# episode  363 score  -58.2 avg score 33.2
# episode  364 score  200.4 avg score 37.2
# episode  365 score  160.8 avg score 41.3
# episode  366 score  159.2 avg score 41.6
# episode  367 score  -60.6 avg score 39.2
# episode  368 score  140.0 avg score 41.1
# episode  369 score  -120.4 avg score 35.5
# episode  370 score  161.4 avg score 39.5
# episode  371 score  -1.6 avg score 36.3
# episode  372 score  -79.6 avg score 34.7
# episode  373 score  -76.3 avg score 35.2
# episode  374 score  -137.0 avg score 33.2
# episode  375 score  -59.6 avg score 28.5
# episode  376 score  163.0 avg score 32.2
# episode  377 score  160.2 avg score 33.3
# episode  378 score  61.4 avg score 34.6
# episode  379 score  140.6 avg score 37.9
# episode  380 score  -57.4 avg score 33.5
# episode  381 score  79.6 avg score 31.1
# episode  382 score  138.7 avg score 33.9
# episode  383 score  42.0 avg score 32.7
# episode  384 score  200.3 avg score 38.3
# episode  385 score  -78.8 avg score 37.9
# episode  386 score  -81.3 avg score 37.1
# episode  387 score  199.7 avg score 43.1
# episode  388 score  -0.0 avg score 45.1
# episode  389 score  -78.6 avg score 43.0
# episode  390 score  100.1 avg score 41.1
# episode  391 score  140.0 avg score 43.5
# episode  392 score  -61.2 avg score 41.5
# episode  393 score  140.3 avg score 45.1
# episode  394 score  79.7 avg score 43.9
# episode  395 score  200.5 avg score 45.9
# episode  396 score  39.2 avg score 46.3
# episode  397 score  201.8 avg score 49.9
# episode  398 score  80.5 avg score 51.5
# episode  399 score  141.1 avg score 53.1
# episode  400 score  -19.1 avg score 52.8
# episode  401 score  201.4 avg score 52.8
# episode  402 score  118.6 avg score 52.9
# episode  403 score  58.1 avg score 55.2
# episode  404 score  77.4 avg score 58.3
# episode  405 score  201.8 avg score 64.3
# episode  406 score  42.5 avg score 62.4
# episode  407 score  139.5 avg score 66.7
# episode  408 score  197.6 avg score 67.5
# episode  409 score  -19.2 avg score 69.1
# episode  410 score  -17.7 avg score 65.2
# episode  411 score  202.6 avg score 70.4
# episode  412 score  -100.4 avg score 65.3
# episode  413 score  22.8 avg score 66.9
# episode  414 score  202.5 avg score 66.9
# episode  415 score  100.5 avg score 65.7
# episode  416 score  -61.0 avg score 61.3
# episode  417 score  39.9 avg score 63.3
# episode  418 score  178.8 avg score 64.1
# episode  419 score  201.5 avg score 70.5
# episode  420 score  -19.4 avg score 66.9
# episode  421 score  138.3 avg score 69.7
# episode  422 score  160.1 avg score 74.5
# episode  423 score  2.6 avg score 76.1
# episode  424 score  201.7 avg score 82.9
# episode  425 score  -20.0 avg score 83.7
# episode  426 score  200.4 avg score 84.4
# episode  427 score  159.6 avg score 84.4
# episode  503 score  57.7 avg score 67.2
# episode  504 score  100.1 avg score 68.8
# episode  505 score  1.8 avg score 70.1
# episode  506 score  -119.0 avg score 65.7
# episode  507 score  -21.5 avg score 62.0
# episode  508 score  21.0 avg score 60.4
# episode  509 score  1.2 avg score 59.7
# episode  510 score  121.0 avg score 58.1
# episode  511 score  -1.2 avg score 55.7
# episode  512 score  60.3 avg score 56.1
# episode  513 score  117.8 avg score 55.6
# episode  514 score  -19.4 avg score 56.1
# episode  515 score  -0.6 avg score 56.0
# episode  516 score  -78.9 avg score 54.0
# episode  517 score  -22.1 avg score 54.4
# episode  518 score  200.6 avg score 55.2
# episode  519 score  198.9 avg score 60.8
# episode  520 score  179.4 avg score 65.2
# episode  521 score  -0.2 avg score 63.3
# episode  522 score  79.1 avg score 64.8
# episode  523 score  -62.2 avg score 64.4
# episode  524 score  -40.8 avg score 61.2
# episode  525 score  -1.2 avg score 57.2
# episode  526 score  -20.9 avg score 52.8
# episode  527 score  139.0 avg score 52.0
# episode  528 score  -77.7 avg score 48.8
# episode  529 score  -41.1 avg score 48.0
# episode  530 score  -41.1 avg score 48.4
# episode  531 score  201.4 avg score 48.5
# episode  532 score  -42.6 avg score 43.6
# episode  533 score  -41.1 avg score 40.8
# episode  534 score  119.7 avg score 40.3
# episode  535 score  -98.5 avg score 38.4
# episode  536 score  -20.4 avg score 38.8
# episode  537 score  119.4 avg score 41.2
# episode  538 score  161.4 avg score 45.2
# episode  539 score  139.5 avg score 46.8
# episode  540 score  -20.3 avg score 47.3
# episode  541 score  -1.5 avg score 47.6
# episode  542 score  -60.1 avg score 42.4
# episode  543 score  119.4 avg score 44.8
# episode  544 score  -0.6 avg score 44.4
# episode  545 score  60.2 avg score 46.1
# episode  546 score  160.0 avg score 46.1
# episode  547 score  -20.3 avg score 41.7
# episode  548 score  -41.3 avg score 40.5
# episode  549 score  160.7 avg score 40.1
# episode  550 score  162.8 avg score 42.6
# episode  551 score  -159.3 avg score 35.4
# episode  552 score  -80.0 avg score 31.0
# episode  553 score  -21.4 avg score 29.4
# episode  554 score  99.0 avg score 29.4
# episode  555 score  80.2 avg score 30.9
# episode  556 score  -17.1 avg score 33.0
# episode  557 score  39.6 avg score 34.2
# episode  558 score  19.4 avg score 34.2
# episode  559 score  60.6 avg score 35.4
# episode  560 score  -120.3 avg score 30.5
# episode  561 score  200.9 avg score 34.6
# episode  562 score  201.7 avg score 37.4
# episode  563 score  179.5 avg score 38.6
# episode  564 score  -40.5 avg score 38.2
# episode  565 score  181.8 avg score 41.9
# episode  566 score  157.9 avg score 46.6
# episode  567 score  -41.6 avg score 46.2
# episode  568 score  180.4 avg score 45.8
# episode  569 score  -20.5 avg score 41.4
# episode  570 score  -37.1 avg score 37.1
# episode  571 score  39.0 avg score 37.9
# episode  572 score  0.8 avg score 36.3
# episode  573 score  18.4 avg score 37.9
# episode  574 score  -2.7 avg score 38.7
# episode  575 score  178.9 avg score 42.3
# episode  576 score  181.9 avg score 46.3
# episode  577 score  -20.3 avg score 43.1
# episode  578 score  -1.3 avg score 44.7
# episode  579 score  -19.1 avg score 45.1
# episode  580 score  -39.9 avg score 45.1
# episode  581 score  200.2 avg score 45.1
# episode  582 score  159.7 avg score 49.2
# episode  583 score  161.4 avg score 53.2
# episode  584 score  21.4 avg score 51.2
# episode  585 score  -40.0 avg score 52.4
# episode  586 score  39.7 avg score 53.6
# episode  587 score  201.7 avg score 55.3
# episode  588 score  179.7 avg score 55.6
# episode  589 score  179.0 avg score 56.4
# episode  590 score  20.4 avg score 57.2
# episode  591 score  -78.9 avg score 55.7
# episode  592 score  -81.2 avg score 55.3
# episode  593 score  79.1 avg score 54.5
# episode  594 score  -18.8 avg score 54.1
# episode  595 score  97.5 avg score 54.8
# episode  596 score  37.9 avg score 52.4
# episode  597 score  -62.7 avg score 51.5
# episode  598 score  -20.0 avg score 52.0
# episode  599 score  -19.6 avg score 48.4
# episode  600 score  81.5 avg score 46.7
# episode  601 score  201.5 avg score 54.0
# episode  602 score  37.7 avg score 56.3
# episode  603 score  -60.4 avg score 55.5
# episode  604 score  199.4 avg score 57.5
# episode  605 score  199.1 avg score 59.9
# episode  606 score  200.8 avg score 64.3
# episode  607 score  -80.7 avg score 61.9
# episode  608 score  -20.7 avg score 61.1
# episode  609 score  201.2 avg score 63.9
# episode  610 score  -78.6 avg score 64.7
# episode  611 score  99.8 avg score 62.7
# episode  612 score  177.9 avg score 62.2
# episode  613 score  -19.4 avg score 58.2
# episode  614 score  120.0 avg score 61.4
# episode  615 score  -59.8 avg score 56.6
# episode  616 score  -43.3 avg score 52.6
# episode  617 score  -41.1 avg score 52.6
# episode  618 score  159.9 avg score 52.2
# episode  619 score  -40.9 avg score 51.8
# episode  620 score  -0.6 avg score 52.5
# episode  621 score  -19.0 avg score 51.3
# episode  622 score  178.7 avg score 54.9
# episode  623 score  100.2 avg score 56.5
# episode  624 score  -1.6 avg score 56.6
# episode  625 score  98.9 avg score 55.0
# episode  626 score  197.0 avg score 55.3
# episode  627 score  158.8 avg score 58.8
# episode  628 score  118.4 avg score 61.2
# episode  629 score  80.4 avg score 63.2
# episode  630 score  59.9 avg score 65.2
# episode  631 score  19.1 avg score 61.6
# episode  632 score  -1.0 avg score 58.4
# episode  633 score  199.9 avg score 59.2
# episode  634 score  -0.3 avg score 58.7
# episode  635 score  140.8 avg score 62.3
# episode  636 score  -20.5 avg score 61.1
# episode  637 score  60.8 avg score 58.3
# episode  638 score  23.0 avg score 55.2
# episode  639 score  18.7 avg score 52.0
# episode  640 score  -21.8 avg score 51.1
# episode  641 score  -81.5 avg score 51.1
# episode  642 score  0.4 avg score 52.7
# episode  643 score  -21.4 avg score 50.7
# episode  644 score  138.3 avg score 53.9
# episode  645 score  -2.1 avg score 51.9
# episode  646 score  178.2 avg score 54.7
# episode  647 score  -77.5 avg score 54.4
# episode  648 score  -60.1 avg score 53.6
# episode  649 score  -20.6 avg score 53.6
# episode  650 score  198.7 avg score 55.9
# episode  651 score  0.3 avg score 51.9
# episode  727 score  62.8 avg score 21.2
# episode  728 score  79.3 avg score 19.6
# episode  729 score  121.2 avg score 22.8
# episode  730 score  -99.4 avg score 17.3
# episode  731 score  199.9 avg score 17.2
# episode  732 score  18.5 avg score 19.6
# episode  733 score  2.6 avg score 19.2
# episode  734 score  180.5 avg score 23.3
# episode  735 score  -39.7 avg score 23.2
# episode  736 score  -0.7 avg score 24.5
# episode  737 score  200.9 avg score 25.3
# episode  738 score  -40.5 avg score 22.1
# episode  739 score  -60.5 avg score 22.1
# episode  740 score  -40.7 avg score 20.4
# episode  741 score  21.0 avg score 22.0
# episode  742 score  -20.2 avg score 20.8
# episode  743 score  -20.7 avg score 20.0
# episode  744 score  37.9 avg score 20.3
# episode  745 score  20.9 avg score 16.7
# episode  746 score  -60.7 avg score 15.5
# episode  747 score  -36.7 avg score 14.8
# episode  748 score  180.7 avg score 20.1
# episode  749 score  119.8 avg score 18.5
# episode  750 score  -39.1 avg score 16.9
# episode  751 score  -79.4 avg score 15.3
# episode  752 score  -0.4 avg score 16.5
# episode  753 score  198.4 avg score 16.5
# episode  754 score  -40.4 avg score 16.8
# episode  755 score  -60.5 avg score 11.7
# episode  756 score  42.1 avg score 14.5
# episode  757 score  -119.0 avg score 12.5
# episode  758 score  60.6 avg score 14.5
# episode  759 score  -39.0 avg score 15.0
# episode  760 score  19.3 avg score 15.8
# episode  761 score  180.8 avg score 20.6
# episode  762 score  199.1 avg score 25.8
# episode  763 score  -41.7 avg score 21.7
# episode  764 score  117.6 avg score 24.9
# episode  765 score  139.2 avg score 28.4
# episode  766 score  18.6 avg score 28.7
# episode  767 score  19.7 avg score 26.3
# episode  768 score  -0.3 avg score 28.3
# episode  769 score  199.8 avg score 33.9
# episode  770 score  17.4 avg score 35.1
# episode  771 score  21.0 avg score 34.7
# episode  772 score  -80.1 avg score 33.2
# episode  773 score  201.3 avg score 38.4
# episode  774 score  -61.3 avg score 35.1
# episode  775 score  40.0 avg score 34.4
# episode  776 score  20.1 avg score 35.2
# episode  777 score  40.5 avg score 34.8
# episode  778 score  -18.8 avg score 32.8
# episode  779 score  159.6 avg score 33.6
# episode  780 score  39.7 avg score 36.3
# episode  781 score  -61.1 avg score 31.1
# episode  782 score  -21.1 avg score 30.3
# episode  783 score  -98.1 avg score 28.3
# episode  784 score  -19.2 avg score 24.3
# episode  785 score  198.6 avg score 29.1
# episode  786 score  -101.1 avg score 27.1
# episode  787 score  -41.0 avg score 22.2
# episode  788 score  -79.6 avg score 21.5
# episode  789 score  -21.9 avg score 22.2
# episode  790 score  -59.4 avg score 21.9
# episode  791 score  161.4 avg score 24.7
# episode  792 score  119.5 avg score 27.5
# episode  793 score  -143.1 avg score 25.0
# episode  794 score  102.8 avg score 26.3
# episode  795 score  138.3 avg score 28.7
# episode  796 score  198.1 avg score 33.8
# episode  797 score  61.8 avg score 35.8
# episode  798 score  41.9 avg score 33.0
# episode  799 score  162.8 avg score 33.9
# episode  800 score  -18.2 avg score 34.3
# episode  801 score  23.0 avg score 36.4
# episode  802 score  -20.0 avg score 36.0
# episode  803 score  199.6 avg score 36.0
# episode  804 score  141.1 avg score 39.6
# episode  805 score  118.8 avg score 43.2
# episode  806 score  -59.9 avg score 41.2
# episode  807 score  -78.2 avg score 42.0
# episode  808 score  -0.0 avg score 40.8
# episode  809 score  -39.1 avg score 40.8
# episode  810 score  99.3 avg score 42.4
# episode  811 score  -79.6 avg score 37.2
# episode  812 score  -1.7 avg score 33.1
# episode  813 score  -40.1 avg score 33.2
# episode  814 score  -19.6 avg score 30.4
# episode  815 score  79.7 avg score 29.2
# episode  816 score  -41.5 avg score 28.0
# episode  817 score  0.2 avg score 27.6
# episode  818 score  -20.3 avg score 27.2
# episode  819 score  180.2 avg score 26.9
# episode  820 score  161.8 avg score 29.7
# episode  821 score  179.6 avg score 32.9
# episode  822 score  -21.5 avg score 34.1
# episode  823 score  179.0 avg score 33.6
# episode  824 score  198.5 avg score 38.8
# episode  825 score  -19.4 avg score 37.6
# episode  826 score  22.3 avg score 37.7
# episode  827 score  -38.0 avg score 36.1
# episode  828 score  158.4 avg score 39.7
# episode  829 score  -19.1 avg score 36.1
# episode  830 score  -20.8 avg score 34.9
# episode  831 score  199.6 avg score 40.1
# episode  832 score  -79.9 avg score 38.9
# episode  833 score  78.3 avg score 42.4
# episode  834 score  200.5 avg score 46.8
# episode  835 score  18.0 avg score 43.2
# episode  836 score  178.2 avg score 48.8
# episode  837 score  199.9 avg score 53.6
# episode  838 score  79.6 avg score 56.8
# episode  839 score  118.9 avg score 59.6
# episode  840 score  -103.4 avg score 58.8
# episode  841 score  21.6 avg score 56.0
# episode  842 score  -59.5 avg score 52.4
# episode  843 score  -19.5 avg score 54.8
# episode  844 score  -42.1 avg score 52.0
# episode  845 score  -17.4 avg score 48.8
# episode  846 score  -59.2 avg score 43.7
# episode  847 score  -21.4 avg score 42.0
# episode  848 score  -56.6 avg score 40.1
# episode  849 score  23.7 avg score 37.3
# episode  850 score  42.4 avg score 38.5
# episode  851 score  -39.9 avg score 37.2
# episode  852 score  20.2 avg score 38.0
# episode  853 score  40.6 avg score 34.9
# episode  854 score  0.7 avg score 32.0
# episode  855 score  180.2 avg score 33.3
# episode  856 score  80.5 avg score 36.1
# episode  857 score  41.4 avg score 38.5
# episode  858 score  20.3 avg score 38.9
# episode  859 score  181.4 avg score 43.3
# episode  860 score  20.1 avg score 41.7
# episode  861 score  59.8 avg score 44.5
# episode  862 score  178.6 avg score 48.1
# episode  863 score  -39.1 avg score 48.1
# episode  864 score  162.0 avg score 51.8
# episode  865 score  17.7 avg score 50.5
# episode  866 score  -78.6 avg score 49.8
# episode  867 score  -22.3 avg score 49.3
# episode  868 score  -22.1 avg score 49.3
# episode  869 score  60.9 avg score 46.9
# episode  870 score  103.0 avg score 45.7
# episode  871 score  21.4 avg score 42.6
# episode  872 score  -39.9 avg score 42.2
# episode  873 score  199.9 avg score 42.6
# episode  874 score  62.3 avg score 39.9
# episode  875 score  -80.9 avg score 38.7
# episode  876 score  79.0 avg score 39.8
# episode  877 score  119.8 avg score 42.9
# episode  878 score  -120.1 avg score 37.4
# episode  879 score  181.4 avg score 41.4
# episode  880 score  -119.3 avg score 39.4
# episode  881 score  -118.7 avg score 33.0
# episode  882 score  -78.4 avg score 33.1
# episode  883 score  199.3 avg score 35.5
# episode  884 score  -81.3 avg score 29.9
# episode  885 score  -41.0 avg score 28.7
# episode  886 score  104.4 avg score 27.2
# episode  887 score  -118.4 avg score 20.8
# episode  888 score  -59.2 avg score 18.1
# episode  889 score  202.4 avg score 19.7
# episode  890 score  0.0 avg score 21.8
# episode  891 score  -41.4 avg score 20.5
# episode  892 score  22.6 avg score 22.2
# episode  893 score  100.2 avg score 24.6
# episode  894 score  99.5 avg score 27.4
# episode  895 score  -142.6 avg score 24.9
# episode  896 score  -20.0 avg score 25.7
# episode  897 score  -81.2 avg score 24.5
# episode  898 score  40.8 avg score 26.4
# episode  899 score  139.5 avg score 28.8
# episode  900 score  83.3 avg score 29.6
# episode  901 score  19.8 avg score 30.8
# episode  902 score  -97.3 avg score 28.4
# episode  903 score  59.4 avg score 28.8
# episode  904 score  197.9 avg score 32.7
# episode  905 score  -98.9 avg score 27.2
# episode  906 score  140.9 avg score 28.4
# episode  907 score  -101.7 avg score 25.5
# episode  908 score  -40.9 avg score 24.3
# episode  909 score  180.5 avg score 24.3
# episode  910 score  22.6 avg score 24.3
# episode  911 score  -0.1 avg score 23.1
# episode  912 score  -20.8 avg score 19.1
# episode  913 score  -120.1 avg score 17.5
# episode  914 score  -80.2 avg score 12.7
# episode  915 score  158.5 avg score 15.5
# episode  916 score  -61.3 avg score 15.8
# episode  917 score  -1.1 avg score 16.2
# episode  918 score  83.7 avg score 18.4
# episode  919 score  -20.1 avg score 16.7
# episode  920 score  18.2 avg score 15.0
# episode  921 score  2.5 avg score 14.7
# episode  922 score  -19.0 avg score 15.1
# episode  923 score  -120.0 avg score 8.7
# episode  924 score  198.3 avg score 11.4
# episode  925 score  -17.8 avg score 12.7
# episode  926 score  22.0 avg score 11.5
# episode  927 score  1.6 avg score 9.2
# episode  928 score  180.5 avg score 15.2
# episode  929 score  40.4 avg score 12.4
# episode  930 score  81.2 avg score 16.4
# episode  931 score  -20.7 avg score 18.3
# episode  932 score  101.3 avg score 21.9
# episode  933 score  179.7 avg score 21.5
# episode  934 score  199.0 avg score 27.1
# episode  935 score  -100.0 avg score 26.0
# episode  936 score  -78.3 avg score 22.3
# episode  937 score  181.7 avg score 28.3
# episode  938 score  199.5 avg score 33.5
# episode  939 score  -102.4 avg score 27.4
# episode  940 score  140.7 avg score 30.2
# episode  941 score  -99.8 avg score 29.0
# episode  942 score  198.9 avg score 32.6
# episode  943 score  61.4 avg score 31.8
# episode  944 score  -58.6 avg score 28.6
# episode  945 score  139.5 avg score 34.3
# episode  946 score  161.2 avg score 37.9
# episode  947 score  -37.9 avg score 38.7
# episode  948 score  -58.8 avg score 36.8
# episode  949 score  158.0 avg score 37.1
# episode  950 score  -60.0 avg score 34.3
# episode  951 score  -119.8 avg score 31.5
# episode  952 score  -19.5 avg score 33.0
# episode  953 score  120.6 avg score 34.2
# episode  954 score  -0.3 avg score 30.3
# episode  955 score  199.5 avg score 36.3
# episode  956 score  200.6 avg score 37.4
# episode  957 score  -0.5 avg score 39.5
# episode  958 score  -60.2 avg score 39.1
# episode  959 score  198.2 avg score 39.4
# episode  960 score  201.2 avg score 43.0
# episode  961 score  199.1 avg score 47.0
# episode  962 score  199.6 avg score 51.4
# episode  963 score  -20.6 avg score 53.4
# episode  964 score  -60.4 avg score 53.8
# episode  965 score  -20.4 avg score 50.2
# episode  966 score  201.4 avg score 55.5
# episode  967 score  198.0 avg score 59.4
# episode  968 score  60.5 avg score 59.0
# episode  969 score  41.5 avg score 60.2
# episode  970 score  -1.7 avg score 59.8
# episode  971 score  138.9 avg score 62.5
# episode  972 score  -39.2 avg score 62.1
# episode  973 score  199.6 avg score 68.5
# episode  974 score  200.8 avg score 68.6
# episode  975 score  161.4 avg score 72.2
# episode  976 score  200.0 avg score 75.7
# episode  977 score  -21.2 avg score 75.3
# episode  978 score  18.7 avg score 72.0
# episode  979 score  -63.7 avg score 69.9
# episode  980 score  -40.1 avg score 67.5
# episode  981 score  36.3 avg score 68.7
# episode  982 score  200.1 avg score 70.6
# episode  983 score  78.7 avg score 68.6
# episode  984 score  120.2 avg score 67.0
# episode  985 score  -57.0 avg score 67.9
# episode  986 score  1.6 avg score 69.5
# episode  987 score  200.1 avg score 69.9
# episode  988 score  -62.5 avg score 64.6
# episode  989 score  -102.9 avg score 64.6
# episode  990 score  160.3 avg score 65.0
# episode  991 score  198.7 avg score 71.0
# episode  992 score  -18.7 avg score 66.6
# episode  993 score  159.9 avg score 68.6
# episode  994 score  -138.5 avg score 67.0
# episode  995 score  200.7 avg score 68.2
# episode  996 score  196.6 avg score 68.9
# episode  997 score  79.3 avg score 71.3
# episode  998 score  159.3 avg score 75.6
# episode  999 score  -58.7 avg score 71.3

# %%
# %% PLOT LEARNING CURVE
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex='all', dpi=200)

## smooth rewards if necessary (moving average)
smoothing_window = n_episodes // 10
smoothed_rewards = np.convolve(score_history, np.ones(smoothing_window)/smoothing_window, mode='valid')
smoothed_actor_losses = np.convolve(actor_losses, np.ones(smoothing_window)/smoothing_window, mode='valid')
smoothed_critic_losses = np.convolve(critic_losses, np.ones(smoothing_window)/smoothing_window, mode='valid')
episodes = np.array(range(n_episodes))[smoothing_window//2:-smoothing_window//2+1]

ax1.plot(episodes, smoothed_rewards)

ax1.set_title("Learning Curve")
ax1.set_xlabel("Episodes")
ax1.set_ylabel("Rewards")

ax2.plot(episodes, smoothed_actor_losses)
ax2.set_xlabel("Episodes")
ax2.set_ylabel("Actor Losses")

ax3.plot(episodes, smoothed_critic_losses)
ax3.set_xlabel("Episodes")
ax3.set_ylabel("Critic Losses")
# Out:
# Text(0, 0.5, 'Critic Losses')

# %% [markdown]
# As you can see, the A2C network learns significantly faster than the REINFORCE one (counted per number of episodes)!
